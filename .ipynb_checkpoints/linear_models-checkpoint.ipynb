# %% [markdown]
# ### <center> Linear Models

# %%
# import important libraries : 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Linear Regression :

# %% [markdown]
# ### The Theory :

# %% [markdown]
# Let the training data $S = \{ (x_1, y_i) \}_{i=0}^{m}$, where $x_i \in \mathbb{R}^d$ and $y_i \in \mathbb{R}$
#
# <u><b>The purpose :</b></u>
#
# Is to find a regressor $h_s$, in the linear regression algorithm :
#
# $$ h_s(x) = w^T.x$$
#
# > Note :
# >
# > $w \in \mathbb{R}^{d+1}$, because we include the bias $w_0$, by including $1$ in sample $x = [1, x_1, ..., x_d ]$
#
# Let define the Loss function, in regression problems, specially in Linear Regression, we consider:
#
# $$ L_s(h_s) = \frac{1}{m} \sum_{i = 1}^{m} (y_i - w^T.x_i)^2 $$
#
# The optimal $w^*$ is given by :
#
# $$ w^* = \arg\min_{w \in \mathbb{R}^{d+1}} L_s(h_s) =  \arg\min_{w \in \mathbb{R}^{d+1}} \frac{1}{m} \sum_{i = 1}^{m} (w^T.x_i - y_i)^2 $$
#
# o solve this problem, we calculate the gradient of the objective function and
# compare it to zero :
#
# $$ \nabla{L_s(h_s)} = \frac{2}{m} \sum_{i = 1}^{m} (w^T.x_i - y_i).x_i$$

# %% [markdown]
# ### Prepare Data :

# %%
data = np.loadtxt("./linreg.csv", delimiter=',')

# %%
data[:10]
# Out:
# array([[ 0.37553646, -2.22354342],
#        [ 0.65627652, -1.40123569],
#        [ 0.71311158, -1.44500759],
#        [ 0.65702952, -1.63459466],
#        [ 0.56116442, -1.70293105],
#        [ 0.05526398, -2.60199084],
#        [ 0.55730574, -1.62237506],
#        [ 0.77161704, -1.17947639],
#        [ 0.94616233, -0.98599069],
#        [ 0.64218085, -1.63081888]])

# %%
X_train, y_train = data[:, 0], data[:, 1]

# %% [markdown]
# ### plot dataset

# %%
plt.scatter(X_train, y_train)

# %% [markdown]
# ### Build Model :

# %%
class LinearRegression:

    def __init__(self, lr=0.01, eps=0.2, name = "Linear Regression"):
        self.lr = lr
        self.eps = eps
        self.w : np.ndarray 
        self.lossHist : list = []
        self.name = name
        self.ls : float
        self.Tmax = 1000
        
    def hs(self, xi):
        return self.w @ xi

    def loss(self, X, y):
        return (1/len(X)) * sum((y[i] - self.hs(xi))**2 for i, xi in enumerate(X))

    def grad(self, X, y):
        return (2/len(X)) * sum( xi*(self.hs(xi) - y[i] ) for i, xi in enumerate(X))

    def _dataVal(self, X, y):
        if X.ndim == 1:
            X = X.reshape(-1, 1)
        if y.ndim == 1:
            y = y.reshape(-1, 1)
        return np.block([np.ones((X.shape[0], 1)), X]), y

    def fit(self, X, y):
        
        X, y = self._dataVal(X, y)
        
        m , d = X.shape
        
        self.w = np.random.rand(d)
        
        self.lossHist.append(self.loss(X, y))

        self.ls = self.loss(X, y)

        t = 0

        for i, xi in range(self.Tmax):
            self.w -= self.lr * self.grad(X, y)

            print(self.grad(X, y))
            
            t += 1                
            self.lossHist.append(self.ls)
            #print(f"iter : {t} ,loss : {self.ls}")

# %%
lg = LinearRegression()

# %%
lg._dataVal(X_train, y_train)
# Out:
# (array([[1.        , 0.37553646],
#         [1.        , 0.65627652],
#         [1.        , 0.71311158],
#         [1.        , 0.65702952],
#         [1.        , 0.56116442],
#         [1.        , 0.05526398],
#         [1.        , 0.55730574],
#         [1.        , 0.77161704],
#         [1.        , 0.94616233],
#         [1.        , 0.64218085],
#         [1.        , 0.37073308],
#         [1.        , 0.8236816 ],
#         [1.        , 0.51156297],
#         [1.        , 0.58911341],
#         [1.        , 0.51435401],
#         [1.        , 0.78597908],
#         [1.        , 0.31322643],
#         [1.        , 0.62173717],
#         [1.        , 0.64851706],
#         [1.        , 0.63886628],
#         [1.        , 0.91319346],
#         [1.        , 0.62661252],
#         [1.        , 0.66840734],
#         [1.        , 0.36829774],
#         [1.        , 0.30610125],
#         [1.        , 0.65382554],
#         [1.        , 0.3212217 ],
#         [1.        , 0.63614662],
#         [1.        , 0.76932384],
#         [1.        , 0.73265958],
#         [1.        , 0.45665064],
#         [1.        , 0.13547419],
#         [1.        , 0.86650912],
#         [1.        , 0.84243042],
#         [1.        , 0.35446574],
#         [1.        , 0.62941392],
#         [1.        , 0.88752528],
#         [1.        , 0.43465742],
#         [1.        , 0.83944282],
#         [1.        , 0.76277215],
#         [1.        , 0.06697062],
#         [1.        , 0.68900439],
#         [1.        , 0.22936725],
#         [1.        , 0.27984515],
#         [1.        , 0.21617027],
#         [1.        , 0.15876301],
#         [1.        , 0.31567907],
#         [1.        , 0.65167531],
#         [1.        , 0.70670809],
#         [1.        , 0.04744192],
#         [1.        , 0.25798666],
#         [1.        , 0.17150646],
#         [1.        , 0.65053841],
#         [1.        , 0.13736793],
#         [1.        , 0.71224482],
#         [1.        , 0.4856361 ],
#         [1.        , 0.32080239],
#         [1.        , 0.58926437],
#         [1.        , 0.41695176],
#         [1.        , 0.93710768],
#         [1.        , 0.77279983],
#         [1.        , 0.05400775],
#         [1.        , 0.68542546],
#         [1.        , 0.37521919],
#         [1.        , 0.55469614],
#         [1.        , 0.50897051],
#         [1.        , 0.65729699],
#         [1.        , 0.95743998],
#         [1.        , 0.2112063 ],
#         [1.        , 0.28124282],
#         [1.        , 0.57988528],
#         [1.        , 0.3163187 ],
#         [1.        , 0.27200931],
#         [1.        , 0.16790849],
#         [1.        , 0.31046489],
#         [1.        , 0.142557  ],
#         [1.        , 0.74315743],
#         [1.        , 0.44981064],
#         [1.        , 0.78644458],
#         [1.        , 0.92504668],
#         [1.        , 0.70673543],
#         [1.        , 0.34687592],
#         [1.        , 0.44148011],
#         [1.        , 0.81616324],
#         [1.        , 0.86919657],
#         [1.        , 0.09523125],
#         [1.        , 0.810197  ],
#         [1.        , 0.3887414 ],
#         [1.        , 0.97152465],
#         [1.        , 0.90153891],
#         [1.        , 0.76628343],
#         [1.        , 0.13004711],
#         [1.        , 0.09431052],
#         [1.        , 0.72176483],
#         [1.        , 0.6294175 ],
#         [1.        , 0.42325286],
#         [1.        , 0.4550977 ],
#         [1.        , 0.45497921],
#         [1.        , 0.78495477],
#         [1.        , 0.9441254 ],
#         [1.        , 0.98798144],
#         [1.        , 0.72687928],
#         [1.        , 0.06665832],
#         [1.        , 0.61784078],
#         [1.        , 0.70833089],
#         [1.        , 0.55138664],
#         [1.        , 0.28129412],
#         [1.        , 0.79607639],
#         [1.        , 0.16006779],
#         [1.        , 0.28280297],
#         [1.        , 0.90451763],
#         [1.        , 0.34547404],
#         [1.        , 0.06277315],
#         [1.        , 0.08304362],
#         [1.        , 0.81514918],
#         [1.        , 0.4648159 ],
#         [1.        , 0.42818168],
#         [1.        , 0.29928963],
#         [1.        , 0.38489479],
#         [1.        , 0.2832807 ],
#         [1.        , 0.43212655],
#         [1.        , 0.37846988],
#         [1.        , 0.18944998],
#         [1.        , 0.70725791],
#         [1.        , 0.635099  ],
#         [1.        , 0.84776484],
#         [1.        , 0.71379196],
#         [1.        , 0.50127049],
#         [1.        , 0.05481349],
#         [1.        , 0.60149496],
#         [1.        , 0.78241633],
#         [1.        , 0.03189624],
#         [1.        , 0.62740425],
#         [1.        , 0.85276279],
#         [1.        , 0.94093137],
#         [1.        , 0.66332161],
#         [1.        , 0.73023333],
#         [1.        , 0.79801914],
#         [1.        , 0.73489963],
#         [1.        , 0.65634013],
#         [1.        , 0.15553079],
#         [1.        , 0.93093046],
#         [1.        , 0.45762935],
#         [1.        , 0.32037085],
#         [1.        , 0.0083994 ],
#         [1.        , 0.65241681],
#         [1.        , 0.34688896],
#         [1.        , 0.23022596],
#         [1.        , 0.47467967],
#         [1.        , 0.9634448 ],
#         [1.        , 0.01584103],
#         [1.        , 0.64808724],
#         [1.        , 0.26759044],
#         [1.        , 0.68203854],
#         [1.        , 0.72237059],
#         [1.        , 0.26584047],
#         [1.        , 0.9190128 ],
#         [1.        , 0.1463937 ],
#         [1.        , 0.70031714],
#         [1.        , 0.13535851],
#         [1.        , 0.9089647 ],
#         [1.        , 0.56609713],
#         [1.        , 0.66579589],
#         [1.        , 0.21816578],
#         [1.        , 0.86211868],
#         [1.        , 0.56061683],
#         [1.        , 0.17790146],
#         [1.        , 0.93182321],
#         [1.        , 0.1541628 ],
#         [1.        , 0.55982305],
#         [1.        , 0.42341206],
#         [1.        , 0.55759077],
#         [1.        , 0.00530117],
#         [1.        , 0.87456385],
#         [1.        , 0.97285298],
#         [1.        , 0.2331312 ],
#         [1.        , 0.52156835],
#         [1.        , 0.14746136],
#         [1.        , 0.6990935 ],
#         [1.        , 0.70721553],
#         [1.        , 0.24411258],
#         [1.        , 0.19591709],
#         [1.        , 0.36240246],
#         [1.        , 0.19864591],
#         [1.        , 0.48191611],
#         [1.        , 0.39239259],
#         [1.        , 0.98290864],
#         [1.        , 0.99132892],
#         [1.        , 0.49192084],
#         [1.        , 0.77249458],
#         [1.        , 0.03602549],
#         [1.        , 0.64891399],
#         [1.        , 0.19499013],
#         [1.        , 0.48269259],
#         [1.        , 0.73364253],
#         [1.        , 0.39572753],
#         [1.        , 0.18994518],
#         [1.        , 0.96527835],
#         [1.        , 0.24245322],
#         [1.        , 0.97167121]]),
#  array([[-2.22354342],
#         [-1.40123569],
#         [-1.44500759],
#         [-1.63459466],
#         [-1.70293105],
#         [-2.60199084],
#         [-1.62237506],
#         [-1.17947639],
#         [-0.98599069],
#         [-1.63081888],
#         [-1.97062529],
#         [-1.15771691],
#         [-1.86694044],
#         [-1.56768912],
#         [-1.8036883 ],
#         [-1.24508779],
#         [-2.07661487],
#         [-1.67647664],
#         [-1.64635429],
#         [-1.62724879],
#         [-0.95142024],
#         [-1.67677174],
#         [-1.60743836],
#         [-2.01270274],
#         [-2.09495012],
#         [-1.39472304],
#         [-2.30983483],
#         [-1.68570659],
#         [-1.44428812],
#         [-1.34555547],
#         [-1.79845579],
#         [-2.53110569],
#         [-0.97283088],
#         [-1.20677277],
#         [-2.00496464],
#         [-1.55169714],
#         [-1.02792367],
#         [-2.03612096],
#         [-1.28287937],
#         [-1.38452796],
#         [-2.68023334],
#         [-1.54728169],
#         [-2.31985796],
#         [-2.14670525],
#         [-2.32939672],
#         [-2.52720554],
#         [-2.36071497],
#         [-1.49231773],
#         [-1.38581506],
#         [-2.62742369],
#         [-2.4015758 ],
#         [-2.60083816],
#         [-1.67189758],
#         [-2.54887864],
#         [-1.57152435],
#         [-2.02025465],
#         [-2.07619809],
#         [-1.60577268],
#         [-1.99078368],
#         [-1.02226817],
#         [-1.2018605 ],
#         [-2.76549266],
#         [-1.3978476 ],
#         [-2.14608138],
#         [-1.65666485],
#         [-1.76710591],
#         [-1.58619164],
#         [-1.07575116],
#         [-2.46876147],
#         [-2.13866557],
#         [-1.61997535],
#         [-2.23002073],
#         [-2.34248369],
#         [-2.44682697],
#         [-2.2602097 ],
#         [-2.52182523],
#         [-1.48416241],
#         [-1.84691233],
#         [-1.17628025],
#         [-1.03742985],
#         [-1.41831589],
#         [-2.20576526],
#         [-2.04157842],
#         [-1.29120332],
#         [-1.10661592],
#         [-2.59706259],
#         [-1.19462768],
#         [-2.05300811],
#         [-0.84946499],
#         [-0.9433533 ],
#         [-1.34615288],
#         [-2.47268497],
#         [-2.66440329],
#         [-1.26046233],
#         [-1.71714263],
#         [-2.11548379],
#         [-1.83534964],
#         [-1.84042729],
#         [-1.29969745],
#         [-0.93175608],
#         [-0.7792794 ],
#         [-1.51506799],
#         [-2.82438345],
#         [-1.74756925],
#         [-1.51419152],
#         [-1.71675079],
#         [-2.32022785],
#         [-1.2100146 ],
#         [-2.44073934],
#         [-2.43090998],
#         [-1.05900907],
#         [-2.23020794],
#         [-2.68646365],
#         [-2.6178929 ],
#         [-1.33476976],
#         [-1.83319801],
#         [-1.97926311],
#         [-2.23427479],
#         [-2.19906996],
#         [-2.19840915],
#         [-2.02197444],
#         [-2.18602706],
#         [-2.59086586],
#         [-1.49739467],
#         [-1.71359967],
#         [-1.30409196],
#         [-1.45560875],
#         [-1.87590221],
#         [-2.86720602],
#         [-1.64516755],
#         [-1.28874748],
#         [-2.88218462],
#         [-1.71790928],
#         [-1.2395314 ],
#         [-1.05723995],
#         [-1.5487437 ],
#         [-1.48421882],
#         [-1.33304033],
#         [-1.29844994],
#         [-1.64971621],
#         [-2.48986676],
#         [-0.98784343],
#         [-1.82982597],
#         [-2.23661842],
#         [-2.70974644],
#         [-1.62355601],
#         [-2.16529185],
#         [-2.27397318],
#         [-1.95165889],
#         [-0.86592812],
#         [-2.93582952],
#         [-1.68261586],
#         [-2.1649554 ],
#         [-1.55916506],
#         [-1.37253108],
#         [-2.170062  ],
#         [-0.86603324],
#         [-2.66993347],
#         [-1.5969397 ],
#         [-2.54231379],
#         [-0.95080305],
#         [-1.82619522],
#         [-1.61128643],
#         [-2.2744939 ],
#         [-1.04667673],
#         [-1.70001317],
#         [-2.48190889],
#         [-0.91515284],
#         [-2.47601234],
#         [-1.67625321],
#         [-1.88069614],
#         [-1.79705153],
#         [-2.70686433],
#         [-1.09281108],
#         [-0.80873627],
#         [-2.42572911],
#         [-1.89607843],
#         [-2.55418864],
#         [-1.3080917 ],
#         [-1.2899006 ],
#         [-2.46060949],
#         [-2.54400072],
#         [-2.24708253],
#         [-2.30516411],
#         [-1.83592631],
#         [-2.20474557],
#         [-0.97583249],
#         [-0.9143968 ],
#         [-1.8759601 ],
#         [-1.17337541],
#         [-2.66767695],
#         [-1.68318859],
#         [-2.56015468],
#         [-1.88786226],
#         [-1.3548225 ],
#         [-2.0509205 ],
#         [-2.61477812],
#         [-0.88563135],
#         [-2.38453419],
#         [-0.89871498]]))

# %%
lg.fit(X_train, y_train)

# %%
lg.w
# Out:
# array([-1.56326243, -0.30520526])
